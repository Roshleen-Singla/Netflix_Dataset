# %%
import pandas as pd

# %%
# !pip install datasets

# %%
df = pd.read_csv("netflix1.csv", encoding='latin1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.head(8790)
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
type(df.date_added[0])
# Out:
# str

# %%
df['date_added'] = pd.to_datetime(df['date_added'], format='mixed')

# %%
df.date_added[0]
# Out:
# Timestamp('2021-09-25 00:00:00')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   datetime64[ns]
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 686.8+ KB

# %%
df['release_year'] = pd.to_datetime(df['release_year'], format='%Y').dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   datetime64[ns]
#  6   release_year  8790 non-null   int32
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: datetime64[ns](1), int32(1), object(8)
# memory usage: 652.5+ KB

# %%
df.release_year[0]
# Out:
# 2020

# %%
df.sort_values("country", inplace = True)

# %%
df
# Out:
#      show_id     type                             title  \
# 3059   s4170    Movie                   Mi Obra Maestra
# 906     s839    Movie             Soy Rada: Serendipity
# 7694   s3824  TV Show          Heidi, bienvenida a casa
# 8490   s6975  TV Show               Historia de un clan
# 7585   s3577  TV Show  Apache: The Life of Carlos Tevez
# ...      ...      ...                               ...
# 835     s743    Movie                  Camellia Sisters
# 720     s570    Movie                       Dreamy Eyes
# 4557   s6318    Movie                     Bitcoin Heist
# 4020   s5613    Movie                 Hitler - A Career
# 1988   s2447    Movie                          Cook Off
#
#                                    director       country date_added  \
# 3059                         GastÃ³n Duprat     Argentina 2019-01-25
# 906                              Pablo Faro     Argentina 2021-05-27
# 7694                              Not Given     Argentina 2019-05-15
# ...

# %%
df.title[41]
# Out:
# 'Mighty Raju'

# %%
df['title'] = df['title'].apply(lambda x: x.encode('latin1').decode('utf-8') if isinstance(x, str) else x)

# %%
df['title']
# Out:
# 3059                     Mi Obra Maestra
# 906                Soy Rada: Serendipity
# 7694            Heidi, bienvenida a casa
# 8490                 Historia de un clan
# 7585    Apache: The Life of Carlos Tevez
#                       ...
# 835                     Camellia Sisters
# 720                          Dreamy Eyes
# 4557                       Bitcoin Heist
# 4020                   Hitler - A Career
# 1988                            Cook Off
# Name: title, Length: 8790, dtype: object

# %%
df[df.title=='Pokémon Master Journeys: The Series']
# Out:
#    show_id     type                                title   director   country  \
# 39     s86  TV Show  Pokémon Master Journeys: The Series  Not Given  Pakistan
#
#    date_added  release_year rating  duration               listed_in
# 39 2021-09-10          2021  TV-Y7  1 Season  Anime Series, Kids' TV

# %%
df['director'] = df['director'].apply(lambda x: x.encode('latin1').decode('utf-8') if isinstance(x, str) else x)

# %%
df['director']
# Out:
# 3059                            Gastón Duprat
# 906                                Pablo Faro
# 7694                                Not Given
# 8490                                Not Given
# 7585                                Not Given
#                         ...
# 835                         Bao Nhan, Namcito
# 720                                 Victor Vu
# 4557                                 Ham Tran
# 4020    Joachim Fest, Christian Herrendoerfer
# 1988                          Tomas Brickhill
# Name: director, Length: 8790, dtype: object

# %%
df['listed_in'].unique()
# Out:
# array(['Comedies, International Movies', 'Stand-Up Comedy',
#        "Kids' TV, Spanish-Language TV Shows",
#        'Crime TV Shows, International TV Shows, Spanish-Language TV Shows',
#        'Dramas, International Movies, Thrillers',
#        'Dramas, International Movies', 'International Movies, Thrillers',
#        'Classic Movies, Dramas, International Movies',
#        'Documentaries, International Movies',
#        'Comedies, Cult Movies, International Movies',
#        'Horror Movies, International Movies, Thrillers',
#        'Dramas, International Movies, Music & Musicals',
#        'Classic & Cult TV, Crime TV Shows, International TV Shows',
#        'International TV Shows, Spanish-Language TV Shows, TV Comedies',
#        "Kids' TV, Spanish-Language TV Shows, Teen TV Shows",
#        'Dramas, Independent Movies, International Movies',
#        'Action & Adventure, Comedies, International Movies',
#        'Action & Adventure, Horror Movies, International Movies',
# ...

# %%
df.groupby('listed_in')['rating'].count()
# Out:
# listed_in
# Action & Adventure                                              128
# Action & Adventure, Anime Features                                1
# Action & Adventure, Anime Features, Children & Family Movies      4
# Action & Adventure, Anime Features, Classic Movies                2
# Action & Adventure, Anime Features, Horror Movies                 1
#                                                                ...
# TV Horror, TV Mysteries, Teen TV Shows                            1
# TV Horror, Teen TV Shows                                          2
# TV Sci-Fi & Fantasy, TV Thrillers                                 1
# TV Shows                                                         16
# Thrillers                                                        65
# Name: rating, Length: 513, dtype: int64

# %%
df['listed_in'] = df['listed_in'].apply(lambda x: x.encode('latin1').decode('utf-8') if isinstance(x, str) else x)

# %%
df['listed_in']
# Out:
# 3059                       Comedies, International Movies
# 906                                       Stand-Up Comedy
# 7694                  Kids' TV, Spanish-Language TV Shows
# 8490    Crime TV Shows, International TV Shows, Spanis...
# 7585    Crime TV Shows, International TV Shows, Spanis...
#                               ...
# 835                          Dramas, International Movies
# 720         Dramas, International Movies, Romantic Movies
# 4557    Action & Adventure, Comedies, International Mo...
# 4020                  Documentaries, International Movies
# 1988      Comedies, International Movies, Romantic Movies
# Name: listed_in, Length: 8790, dtype: object

# %%
df.groupby('rating')['listed_in'].count()
# Out:
# rating
# G             41
# NC-17          3
# NR            79
# PG           287
# PG-13        490
# R            799
# TV-14       2157
# TV-G         220
# TV-MA       3205
# TV-PG        861
# TV-Y         306
# TV-Y7        333
# TV-Y7-FV       6
# UR             3
# Name: listed_in, dtype: int64

# %%
df.groupby('rating')['listed_in'].agg(['max', 'count'])
# Out:
#                                                         max  count
# rating
# G                           Documentaries, Music & Musicals     41
# NC-17      Dramas, Independent Movies, International Movies      3
# NR                                          Stand-Up Comedy     79
# PG                                    Dramas, Sports Movies    287
# PG-13                                             Thrillers    490
# R                                                 Thrillers    799
# TV-14                                             Thrillers   2157
# TV-G                                               TV Shows    220
# TV-MA                                             Thrillers   3205
# TV-PG                        TV Dramas, TV Sci-Fi & Fantasy    861
# TV-Y                                                 Movies    306
# TV-Y7                                                Movies    333
# TV-Y7-FV  Kids' TV, TV Action & Adventure, TV Sci-Fi & F...      6
# ...

# %%
# Save cleaned data to a new CSV file
df.to_csv('netflix_cleaned_dataset.csv', index=False)
